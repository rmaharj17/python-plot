# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import matplotlib.ticker as tck
import csv

'''
with open('rdf_water_298.csv', 'r') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    distance = []
    rdf_OO = []
    error_OO = []
    rdf_OH = []
    error_OH = []
    rdf_HH = []
    error_HH = []
    for col in readCSV:
        distance.append(float(col[0]))
        rdf_OO.append(float(col[1]))
        error_OO.append(float(col[2]))
        rdf_OH.append(float(col[3]))
        error_OH.append(float(col[4]))
        rdf_HH.append(float(col[5]))
        error_HH.append(float(col[6]))
'''

with open('rdf_water_298K_cutoff.csv', 'r') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    distance = []
    rdf_OO = []
    for col in readCSV:
        distance.append(float(col[0]))
        rdf_OO.append(float(col[1]))


with open('shw_298.15.csv', 'r') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    shw_distance = []
    shw_rdf_OO = []
    for col in readCSV:
        shw_distance.append(float(col[0]))
        shw_rdf_OO.append(float(col[1]))

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(1, 1, 1)

ax.plot(distance, rdf_OO, label='expt_RDF_O-O', linestyle = '--', linewidth = 1.5)
ax.plot(shw_distance, shw_rdf_OO, label='shw_RDF_O-O', linestyle = '--', linewidth = 1.5)

plt.ylabel('g(r)', fontsize = 15)
plt.xlabel('Distance, A', fontsize = 15)
plt.title('Radial Distribution Function for O-O', fontsize = 20)
# plt.ylim(40, 160)
# plt.xlim(10, 1000000)
ax.yaxis.set_minor_locator(tck.AutoMinorLocator())
ax.xaxis.set_minor_locator(tck.AutoMinorLocator())
# plt.xticks(ind, ('10', '100', '1000', '10000', '10E+05', '10E+06'), ha = 'center', va = 'top')
plt.legend(loc='best', fontsize = 10)

# Tick Parameters
plt.tick_params(axis='both', left='on', top='on', right='on',
                    bottom='on', labelleft='on', labeltop='off',
                    labelright='off', labelbottom='on', direction = 'in', which='major', labelsize=15)

'''
ax.set_ylabel('Scores')
ax.set_xticks(ind+width)
ax.set_xticklabels( ('2011-Jan-4', '2011-Jan-5', '2011-Jan-6') )
ax.legend( (rects1[0], rects2[0], rects3[0]), ('y', 'z', 'k') )
'''
# saving figure
plt.savefig("rdf.png", bbox_inches="tight", dpi = 500)
# plt.grid()
plt.show()
